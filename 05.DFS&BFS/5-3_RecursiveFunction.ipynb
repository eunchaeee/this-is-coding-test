# %%
def recursive_function():
    print("재귀함수 호출")
    recursive_function()

recursive_function()
# Out:
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# ...
